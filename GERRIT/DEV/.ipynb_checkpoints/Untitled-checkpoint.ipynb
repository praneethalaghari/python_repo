# %%
import array

arr = array.array('i',[3,2,4,6,2])
arr = sorted(arr)[::-1]
print('{}'.format(arr))

n = 15
count = 0

ways = []

for i in range(len(arr)):
    
    for j in range(i,len(arr)):
        #sub_way = []
        #sub_way.append(arr[i])

        temp = arr[i]
        print("Checking with ",arr[i])
        while j < len(arr): 
            print(' and ',arr[j],sep='',end='')
            print('\n')
            
            #sub_way.append(arr[j])
            #print(sub_way)
            add = temp
            add = add + arr[j]

            if add < n:
                temp = add
                temp_subway = sub_way
            elif add == n:
                count +=1
                temp = arr[i]
                #ways.append(sub_way)
                #sub_way=[]
                j+=1
            elif add > n:
                j+=1
                #sub_way=[]

    
print(count)
print(ways)
# Out:
# [6, 4, 3, 2, 2]
# Checking with  6
#  and 6
#
# [6, 6]
#  and 6
#
# [6, 6, 6]
#  and 4
#
# [4]
#  and 3
#
# [3]
#  and 2
#
# [2]
#  and 2
#
# [2, 2]
#  and 2
#
# [2, 2, 2]
#  and 2
#
# [2, 2, 2, 2]
#  and 2
#
# [2, 2, 2, 2, 2]
#  and 2
#
# [2]
# Checking with  6
#  and 4
#
# [6, 4]
#  and 4
#
# [6, 4, 4]
#  and 4
#
# [6, 4, 4, 4]
#  and 3
#
# [3]
#  and 2
#
# [2]
#  and 2
#
# [2]
# Checking with  6
#  and 3
#
# [6, 3]
#  and 3
#
# [6, 3, 3]
#  and 3
#
# [6, 3, 3, 3]
#  and 2
#
# [2]
#  and 2
#
# [2, 2]
#  and 2
#
# [2, 2, 2]
#  and 2
#
# [2, 2, 2, 2]
#  and 2
#
# [2, 2, 2, 2, 2]
#  and 2
#
# [2]
# Checking with  6
#  and 2
#
# [6, 2]
#  and 2
#
# [6, 2, 2]
#  and 2
#
# [6, 2, 2, 2]
#  and 2
#
# [6, 2, 2, 2, 2]
#  and 2
#
# [6, 2, 2, 2, 2, 2]
#  and 2
#
# [2]
# Checking with  6
#  and 2
#
# [6, 2]
#  and 2
#
# [6, 2, 2]
#  and 2
#
# [6, 2, 2, 2]
#  and 2
#
# [6, 2, 2, 2, 2]
#  and 2
#
# [6, 2, 2, 2, 2, 2]
# Checking with  4
#  and 4
#
# [4, 4]
#  and 4
#
# [4, 4, 4]
#  and 4
#
# ...

# %%
# Out:
# [4, 3, 2]
# Checking with  4 and 4
#
# adding  4 4
# 8
#  and 3
#
# adding  4 3
# 7
#  and 3
#
# adding  7 3
# 10
#  and 2
#
# adding  7 2
# 9
# Checking with  4 and 3
#
# adding  4 3
# 7
#  and 3
#
# adding  7 3
# 10
#  and 2
#
# adding  7 2
# 9
# Checking with  4 and 2
#
# adding  4 2
# 6
#  and 2
#
# adding  6 2
# 8
# Checking with  3 and 3
#
# adding  3 3
# 6
#  and 3
#
# adding  6 3
# 9
#  and 2
#
# adding  6 2
# 8
# Checking with  3 and 2
#
# adding  3 2
# 5
#  and 2
#
# adding  5 2
# 7
#  and 2
#
# adding  7 2
# 9
# Checking with  2 and 2
#
# adding  2 2
# 4
#  and 2
#
# adding  4 2
# 6
#  and 2
#
# adding  6 2
# 8
# 4
